# %%
pip install streamlit transformers torchaudio ffmpeg-python
# Out:
# Requirement already satisfied: streamlit in c:\anaconda\envs\task\lib\site-packages (1.45.1)
# Requirement already satisfied: transformers in c:\anaconda\envs\task\lib\site-packages (4.53.0.dev0)
# Requirement already satisfied: torchaudio in c:\anaconda\envs\task\lib\site-packages (2.7.0)
# Requirement already satisfied: ffmpeg-python in c:\anaconda\envs\task\lib\site-packages (0.2.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging<25,>=20 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (6.31.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (4.13.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\anaconda\envs\task\lib\site-packages (from streamlit) (6.5)
# Requirement already satisfied: jinja2 in c:\anaconda\envs\task\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\anaconda\envs\task\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\anaconda\envs\task\lib\site-packages (from altair<6,>=4.0->streamlit) (1.40.0)
# Requirement already satisfied: colorama in c:\anaconda\envs\task\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\anaconda\envs\task\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\anaconda\envs\task\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\envs\task\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\envs\task\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda\envs\task\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\envs\task\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\envs\task\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\envs\task\lib\site-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\envs\task\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: filelock in c:\anaconda\envs\task\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\anaconda\envs\task\lib\site-packages (from transformers) (0.32.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda\envs\task\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\anaconda\envs\task\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\anaconda\envs\task\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\anaconda\envs\task\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\anaconda\envs\task\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda\envs\task\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.5.0)
# Requirement already satisfied: torch==2.7.0 in c:\anaconda\envs\task\lib\site-packages (from torchaudio) (2.7.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\anaconda\envs\task\lib\site-packages (from torch==2.7.0->torchaudio) (1.14.0)
# Requirement already satisfied: networkx in c:\anaconda\envs\task\lib\site-packages (from torch==2.7.0->torchaudio) (3.4.2)
# Requirement already satisfied: future in c:\anaconda\envs\task\lib\site-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\envs\task\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\anaconda\envs\task\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\anaconda\envs\task\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\anaconda\envs\task\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\anaconda\envs\task\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda\envs\task\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\envs\task\lib\site-packages (from sympy>=1.13.3->torch==2.7.0->torchaudio) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile app.py

import streamlit as st
import ffmpeg
import torchaudio
from transformers import AutoModelForAudioClassification, AutoFeatureExtractor
import torch
import tempfile
import os

# Function to extract audio
def extract_audio(video_path, audio_path):
    try:
        ffmpeg.input(video_path).output(audio_path, format='wav', acodec='pcm_s16le', ac=1, ar='16000').overwrite_output().run(quiet=True)
    except ffmpeg.Error as e:
        st.error("Audio extraction failed.")
        st.stop()
    return audio_path

# Load model and feature extractor
@st.cache_resource
def load_model():
    model_name = "HamzaSidhu786/speech-accent-detection"
    model = AutoModelForAudioClassification.from_pretrained(model_name)
    extractor = AutoFeatureExtractor.from_pretrained(model_name)
    return model, extractor

# Predict accent
def predict_accent(audio_path, model, extractor):
    waveform, sr = torchaudio.load(audio_path)
    if sr != 16000:
        waveform = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)(waveform)
    inputs = extractor(waveform.squeeze().numpy(), sampling_rate=16000, return_tensors="pt")
    with torch.no_grad():
        logits = model(**inputs).logits
    pred_id = torch.argmax(logits, dim=-1).item()
    return model.config.id2label[pred_id]

# Streamlit UI
st.title("Accent Detection from Video")
st.write("Upload a video to detect the speaker's accent.")

uploaded = st.file_uploader("Upload a video", type=["mp4", "mov", "avi", "mkv"])

if uploaded:
    with tempfile.NamedTemporaryFile(delete=False, suffix=".mp4") as tmp_vid:
        tmp_vid.write(uploaded.read())
        video_path = tmp_vid.name

    with tempfile.NamedTemporaryFile(delete=False, suffix=".wav") as tmp_aud:
        audio_path = tmp_aud.name

    st.info("Extracting audio...")
    extract_audio(video_path, audio_path)

    st.info("Loading model...")
    model, extractor = load_model()

    st.info("Detecting accent...")
    accent = predict_accent(audio_path, model, extractor)
    st.success(f"Detected Accent: **{accent}**")

    os.remove(video_path)
    os.remove(audio_path)

# %%
# !streamlit run app.py
